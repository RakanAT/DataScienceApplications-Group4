# %% [markdown]
# # Genre Classifier
# Trains **Logistic Regression**, **SVM**, **Random Forest**, **Naïve Bayes**, **KNN**, and **XGBoost** models to classify book genre from
# 100-word text partitions.
#
# **Inputs required (run the other notebooks first):**
# - `partitions.csv` — from `book_partitioner.ipynb`
# - `vocabulary.csv` — from `book_ngram_analysis.ipynb`
#
# **Outputs:** accuracy scores, classification reports, and confusion matrices.

# %%
import pandas as pd
import numpy as np
import re
from pathlib import Path
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_predict
from sklearn.metrics import (
    accuracy_score, classification_report,
    confusion_matrix, ConfusionMatrixDisplay
)
from sklearn.pipeline import Pipeline
import joblib

# %% [markdown]
# ## Configuration

# %%
PARTITIONS_CSV = "partitions.csv"   # output of book_partitioner.ipynb
VOCABULARY_CSV = "vocabulary.csv"   # output of book_ngram_analysis.ipynb

TEST_SIZE      = 0.2    # 80/20 train-test split
RANDOM_STATE   = 42
CV_FOLDS       = 5      # stratified k-fold cross-validation

# Genres in a consistent display order
GENRES = ["autobiography", "fantasy", "horror", "romance", "sci-fi"]

# %% [markdown]
# ## Load Data

# %%
partitions = pd.read_csv(PARTITIONS_CSV)
vocabulary  = pd.read_csv(VOCABULARY_CSV)["word"].tolist()

print(f"Partitions loaded : {len(partitions):,} rows")
print(f"Vocabulary size   : {len(vocabulary):,} words")
print(f"\nGenre distribution:")
print(partitions['genre'].value_counts().to_string())
partitions.head(3)
# Out:
# Partitions loaded : 1,000 rows
# Vocabulary size   : 1,259 words
#
# Genre distribution:
# genre
# fantasy          200
# romance          200
# sci-fi           200
# horror           200
# autobiography    200
#                          partition_id                    book    genre  \
# 0  TheWonderfulWizardOfOz_partition_a  TheWonderfulWizardOfOz  fantasy
# 1  TheWonderfulWizardOfOz_partition_b  TheWonderfulWizardOfOz  fantasy
# 2  TheWonderfulWizardOfOz_partition_c  TheWonderfulWizardOfOz  fantasy
#
#    start_token                                               text  word_count
# 0         7296  at the tin legs, which hurt his teeth. “Did yo...         100
# 1         1639  her eyes growing bigger and bigger at the wond...         100
# 2        18024  him your message. He said he will grant you an...         100

# %% [markdown]
# ## Testing All Models with All 3 Vectorizers
# Methods include BOW, TF-IDF, and TF-IDF N-grams

# %%
from sklearn.base import clone
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.preprocessing import LabelEncoder

X_text = partitions["text"].tolist()
y      = partitions["genre"].tolist()

# Define three vectorizers
methods = {
    "Bag of Words": CountVectorizer(vocabulary=vocabulary, token_pattern=r'[a-z]+'),
    "TF-IDF": TfidfVectorizer(vocabulary=vocabulary, sublinear_tf=True, token_pattern=r'[a-z]+'),
    "TF-IDF N-grams": TfidfVectorizer(vocabulary=vocabulary, sublinear_tf=True, token_pattern=r'[a-z]+', ngram_range=(1, 2))
}

# For testing removal of vocabulary restriction:
""" methods = {
    "Bag of Words": CountVectorizer(token_pattern=r'[a-z]+', min_df=3, max_df=0.7),
    "TF-IDF": TfidfVectorizer(sublinear_tf=True, token_pattern=r'[a-z]+', min_df=3, max_df=0.7),
    "TF-IDF N-grams": TfidfVectorizer(sublinear_tf=True, token_pattern=r'[a-z]+', ngram_range=(1, 2), min_df=3, max_df=0.7)
} """

models_to_test = {
    "Logistic Regression": LogisticRegression(
        max_iter=1000,
        random_state=RANDOM_STATE,
        C=1.0,
        solver='lbfgs',
        multi_class='multinomial',
    ),
    "SVM": LinearSVC(
        max_iter=2000,
        random_state=RANDOM_STATE,
        C=1.0,
    ),
    "Random Forest": RandomForestClassifier(
        n_estimators=200,
        random_state=RANDOM_STATE,
        n_jobs=-1,
    ),
    "Multinomial Naïve Bayes": MultinomialNB(
        alpha=1.0
    ),
    "K-Nearest Neighbors": KNeighborsClassifier(
        n_neighbors=5, 
        n_jobs=-1
    ),
    "XGBoost": XGBClassifier(
        n_estimators=200,
        max_depth=6,
        learning_rate=0.1,
        random_state=RANDOM_STATE,
        tree_method='hist',
        n_jobs=-1,
        verbosity=0,
    ),
}

for method_name, vectorizer in methods.items():
    print(f"\n=== Vectorizer: {method_name} ===")
    X = vectorizer.fit_transform(X_text)
    X_train, X_test, y_train, y_test = train_test_split(
        X, y,
        test_size=TEST_SIZE,
        random_state=RANDOM_STATE,
        stratify=y,
    )

    for model_name, model in models_to_test.items():
        model_clone = clone(model)
        
        if model_name == "XGBoost":
            le = LabelEncoder()
            y_train_encoded = le.fit_transform(y_train)
            model_clone.fit(X_train, y_train_encoded)
            y_pred = le.inverse_transform(model_clone.predict(X_test))
        else:
            model_clone.fit(X_train, y_train)
            y_pred = model_clone.predict(X_test)

        print(f"\n>> {model_name}")
        print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")
        print(classification_report(y_test, y_pred, target_names=GENRES))
# Out:
# === Vectorizer: Bag of Words ===
#
# >> Logistic Regression
# Accuracy: 0.8900
#                precision    recall  f1-score   support
#
# autobiography       0.77      0.85      0.81        40
#       fantasy       0.95      0.97      0.96        40
#        horror       0.94      0.78      0.85        40
#       romance       0.81      0.88      0.84        40
#        sci-fi       1.00      0.97      0.99        40
#
#      accuracy                           0.89       200
#     macro avg       0.90      0.89      0.89       200
#  weighted avg       0.90      0.89      0.89       200
#
#
# >> SVM
# Accuracy: 0.8900
#                precision    recall  f1-score   support
#
# autobiography       0.83      0.85      0.84        40
#       fantasy       0.91      0.97      0.94        40
#        horror       0.94      0.75      0.83        40
#       romance       0.82      0.90      0.86        40
#        sci-fi       0.97      0.97      0.97        40
#
#      accuracy                           0.89       200
#     macro avg       0.89      0.89      0.89       200
#  weighted avg       0.89      0.89      0.89       200
#
#
# >> Random Forest
# Accuracy: 0.9000
#                precision    recall  f1-score   support
#
# autobiography       0.77      0.85      0.81        40
#       fantasy       0.95      0.95      0.95        40
#        horror       0.90      0.88      0.89        40
#       romance       0.94      0.82      0.88        40
#        sci-fi       0.95      1.00      0.98        40
#
#      accuracy                           0.90       200
#     macro avg       0.90      0.90      0.90       200
#  weighted avg       0.90      0.90      0.90       200
#
#
# >> Multinomial Naïve Bayes
# Accuracy: 0.8900
#                precision    recall  f1-score   support
#
# autobiography       0.88      0.88      0.88        40
#       fantasy       0.81      0.97      0.89        40
#        horror       0.91      0.75      0.82        40
#       romance       0.88      0.88      0.88        40
#        sci-fi       1.00      0.97      0.99        40
#
#      accuracy                           0.89       200
#     macro avg       0.89      0.89      0.89       200
#  weighted avg       0.89      0.89      0.89       200
#
#
# >> K-Nearest Neighbors
# Accuracy: 0.5650
#                precision    recall  f1-score   support
#
# autobiography       0.37      0.88      0.52        40
#       fantasy       0.88      0.53      0.66        40
#        horror       0.53      0.57      0.55        40
#       romance       0.76      0.33      0.46        40
#        sci-fi       1.00      0.53      0.69        40
#
#      accuracy                           0.56       200
#     macro avg       0.71      0.56      0.57       200
#  weighted avg       0.71      0.56      0.57       200
#
#
# >> XGBoost
# Accuracy: 0.8850
#                precision    recall  f1-score   support
#
# autobiography       0.78      0.90      0.84        40
#       fantasy       0.93      0.95      0.94        40
#        horror       0.86      0.80      0.83        40
#       romance       0.89      0.78      0.83        40
#        sci-fi       0.98      1.00      0.99        40
#
#      accuracy                           0.89       200
#     macro avg       0.89      0.89      0.88       200
#  weighted avg       0.89      0.89      0.88       200
#
#
# === Vectorizer: TF-IDF ===
#
# >> Logistic Regression
# Accuracy: 0.9100
#                precision    recall  f1-score   support
#
# autobiography       0.80      0.88      0.83        40
#       fantasy       0.95      1.00      0.98        40
#        horror       0.94      0.82      0.88        40
#       romance       0.88      0.88      0.88        40
#        sci-fi       1.00      0.97      0.99        40
#
#      accuracy                           0.91       200
#     macro avg       0.91      0.91      0.91       200
#  weighted avg       0.91      0.91      0.91       200
#
#
# >> SVM
# Accuracy: 0.8850
#                precision    recall  f1-score   support
#
# autobiography       0.85      0.85      0.85        40
#       fantasy       0.89      1.00      0.94        40
#        horror       0.94      0.72      0.82        40
#       romance       0.80      0.88      0.83        40
#        sci-fi       0.97      0.97      0.97        40
#
#      accuracy                           0.89       200
#     macro avg       0.89      0.89      0.88       200
#  weighted avg       0.89      0.89      0.88       200
#
#
# >> Random Forest
# Accuracy: 0.8950
#                precision    recall  f1-score   support
#
# autobiography       0.80      0.88      0.83        40
#       fantasy       0.89      0.97      0.93        40
#        horror       0.94      0.82      0.88        40
#       romance       0.91      0.80      0.85        40
#        sci-fi       0.95      1.00      0.98        40
#
#      accuracy                           0.90       200
#     macro avg       0.90      0.89      0.89       200
#  weighted avg       0.90      0.90      0.89       200
#
#
# >> Multinomial Naïve Bayes
# Accuracy: 0.8950
#                precision    recall  f1-score   support
#
# autobiography       0.88      0.88      0.88        40
#       fantasy       0.83      0.97      0.90        40
#        horror       0.94      0.75      0.83        40
#       romance       0.86      0.90      0.88        40
#        sci-fi       1.00      0.97      0.99        40
#
#      accuracy                           0.90       200
#     macro avg       0.90      0.89      0.89       200
#  weighted avg       0.90      0.90      0.89       200
#
#
# >> K-Nearest Neighbors
# Accuracy: 0.8450
#                precision    recall  f1-score   support
#
# autobiography       0.70      0.88      0.78        40
#       fantasy       0.78      0.97      0.87        40
#        horror       0.96      0.62      0.76        40
#       romance       0.89      0.78      0.83        40
#        sci-fi       1.00      0.97      0.99        40
#
#      accuracy                           0.84       200
#     macro avg       0.87      0.84      0.84       200
#  weighted avg       0.87      0.84      0.84       200
#
#
# >> XGBoost
# Accuracy: 0.8950
#                precision    recall  f1-score   support
#
# autobiography       0.81      0.88      0.84        40
#       fantasy       0.95      0.97      0.96        40
#        horror       0.92      0.85      0.88        40
#       romance       0.86      0.78      0.82        40
#        sci-fi       0.93      1.00      0.96        40
#
#      accuracy                           0.90       200
#     macro avg       0.90      0.89      0.89       200
#  weighted avg       0.90      0.90      0.89       200
#
#
# === Vectorizer: TF-IDF N-grams ===
#
# >> Logistic Regression
# Accuracy: 0.9150
#                precision    recall  f1-score   support
#
# autobiography       0.83      0.88      0.85        40
#       fantasy       0.95      1.00      0.98        40
#        horror       0.94      0.82      0.88        40
#       romance       0.86      0.90      0.88        40
#        sci-fi       1.00      0.97      0.99        40
#
#      accuracy                           0.92       200
#     macro avg       0.92      0.92      0.91       200
#  weighted avg       0.92      0.92      0.91       200
#
#
# >> SVM
# Accuracy: 0.8950
#                precision    recall  f1-score   support
#
# autobiography       0.81      0.85      0.83        40
#       fantasy       0.93      1.00      0.96        40
#        horror       0.94      0.78      0.85        40
#       romance       0.83      0.88      0.85        40
#        sci-fi       0.97      0.97      0.97        40
#
#      accuracy                           0.90       200
#     macro avg       0.90      0.89      0.89       200
#  weighted avg       0.90      0.90      0.89       200
#
#
# >> Random Forest
# Accuracy: 0.9100
#                precision    recall  f1-score   support
#
# autobiography       0.88      0.88      0.88        40
#       fantasy       0.93      0.95      0.94        40
#        horror       0.88      0.90      0.89        40
#       romance       0.92      0.82      0.87        40
#        sci-fi       0.95      1.00      0.98        40
#
#      accuracy                           0.91       200
#     macro avg       0.91      0.91      0.91       200
#  weighted avg       0.91      0.91      0.91       200
#
#
# >> Multinomial Naïve Bayes
# Accuracy: 0.9100
#                precision    recall  f1-score   support
#
# autobiography       0.88      0.90      0.89        40
#       fantasy       0.85      1.00      0.92        40
#        horror       0.97      0.78      0.86        40
#       romance       0.88      0.90      0.89        40
#        sci-fi       1.00      0.97      0.99        40
#
#      accuracy                           0.91       200
#     macro avg       0.92      0.91      0.91       200
#  weighted avg       0.92      0.91      0.91       200
#
#
# >> K-Nearest Neighbors
# Accuracy: 0.8250
#                precision    recall  f1-score   support
#
# autobiography       0.67      0.85      0.75        40
#       fantasy       0.74      0.97      0.84        40
#        horror       0.96      0.60      0.74        40
#       romance       0.91      0.75      0.82        40
#        sci-fi       1.00      0.95      0.97        40
#
#      accuracy                           0.82       200
#     macro avg       0.85      0.82      0.82       200
#  weighted avg       0.85      0.82      0.82       200
#
#
# >> XGBoost
# Accuracy: 0.8550
#                precision    recall  f1-score   support
#
# autobiography       0.77      0.82      0.80        40
#       fantasy       0.90      0.90      0.90        40
#        horror       0.84      0.80      0.82        40
#       romance       0.81      0.75      0.78        40
#        sci-fi       0.95      1.00      0.98        40
#
#      accuracy                           0.85       200
#     macro avg       0.85      0.86      0.85       200
#  weighted avg       0.85      0.85      0.85       200

# %% [markdown]
# ## 10-Fold Cross Validation

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.preprocessing import LabelEncoder
import pandas as pd
import numpy as np

# Pre-encode labels once
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# Setup Cross-Validation
cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=RANDOM_STATE)

# Store results 
results = []

for method_name, vectorizer in methods.items():
    print(f"\nProcessing Vectorizer: {method_name}...")
    X = vectorizer.fit_transform(X_text)
    
    for model_name, model in models_to_test.items():
        # Get 10 scores
        scores = cross_val_score(model, X, y_encoded, cv=cv, scoring='accuracy')
        
        # Save results to a list for analysis
        results.append({
            "Vectorizer": method_name,
            "Model": model_name,
            "Mean_Accuracy": np.mean(scores),
            "Std_Dev": np.std(scores)
        })
        
        print(f"  {model_name}: {np.mean(scores):.4f} (+/- {np.std(scores):.4f})")

# Convert to DataFrame to find champion
results_df = pd.DataFrame(results)
print("\n--- Final Summary ---")
print(results_df.sort_values(by="Mean_Accuracy", ascending=False).to_string(index=False))
# Out:
# Processing Vectorizer: Bag of Words...
#   Logistic Regression: 0.8780 (+/- 0.0316)
#   SVM: 0.8610 (+/- 0.0251)
#   Random Forest: 0.8840 (+/- 0.0385)
#   Multinomial Naïve Bayes: 0.9150 (+/- 0.0258)
#   K-Nearest Neighbors: 0.5050 (+/- 0.0522)
#   XGBoost: 0.8610 (+/- 0.0284)
#
# Processing Vectorizer: TF-IDF...
#   Logistic Regression: 0.9100 (+/- 0.0214)
#   SVM: 0.9000 (+/- 0.0245)
#   Random Forest: 0.8810 (+/- 0.0324)
#   Multinomial Naïve Bayes: 0.9160 (+/- 0.0211)
#   K-Nearest Neighbors: 0.8400 (+/- 0.0397)
#   XGBoost: 0.8350 (+/- 0.0364)
#
# Processing Vectorizer: TF-IDF N-grams...
#   Logistic Regression: 0.9220 (+/- 0.0194)
#   SVM: 0.9140 (+/- 0.0206)
#   Random Forest: 0.8800 (+/- 0.0316)
#   Multinomial Naïve Bayes: 0.9260 (+/- 0.0301)
#   K-Nearest Neighbors: 0.8370 (+/- 0.0237)
#   XGBoost: 0.8440 (+/- 0.0304)
#
# --- Final Summary ---
#     Vectorizer                   Model  Mean_Accuracy  Std_Dev
# TF-IDF N-grams Multinomial Naïve Bayes          0.926 0.030067
# TF-IDF N-grams     Logistic Regression          0.922 0.019391
#         TF-IDF Multinomial Naïve Bayes          0.916 0.021071
#   Bag of Words Multinomial Naïve Bayes          0.915 0.025788
# TF-IDF N-grams                     SVM          0.914 0.020591
#         TF-IDF     Logistic Regression          0.910 0.021448
#         TF-IDF                     SVM          0.900 0.024495
#   Bag of Words           Random Forest          0.884 0.038523
#         TF-IDF           Random Forest          0.881 0.032388
# TF-IDF N-grams           Random Forest          0.880 0.031623
#   Bag of Words     Logistic Regression          0.878 0.031559
#   Bag of Words                     SVM          0.861 0.025080
#   Bag of Words                 XGBoost          0.861 0.028443
# TF-IDF N-grams                 XGBoost          0.844 0.030397
#         TF-IDF     K-Nearest Neighbors          0.840 0.039749
# TF-IDF N-grams     K-Nearest Neighbors          0.837 0.023685
#         TF-IDF                 XGBoost          0.835 0.036401
#   Bag of Words     K-Nearest Neighbors          0.505 0.052202

# %% [markdown]
# ## Feature Importance for All Models

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.base import clone

# Encode labels 
le = LabelEncoder()
y_encoded = le.fit_transform(y)

def audit_all_models(methods, models, X_data, y_encoded_data):
    for method_name, vectorizer in methods.items():
        print(f"\n{'='*20}\nAUDIT: {method_name}\n{'='*20}")
        
        # Transform data
        X = vectorizer.fit_transform(X_data)
        feature_names = vectorizer.get_feature_names_out()
        
        for model_name, model in models.items():
            print(f"\n--- Model: {model_name} ---")
            
            # Create a fresh, empty copy
            model_clone = clone(model)
            
            # Fit using the encoded labels
            model_clone.fit(X, y_encoded_data)
            
            # Extract weights based on model type
            if hasattr(model_clone, 'coef_'):
                # For Linear models (Logistic/SVM), coef_ is usually shape (n_classes, n_features)
                # If binary, it's (1, n_features). If multiclass, it's (n_classes, n_features)
                if model_clone.coef_.shape[0] == 1:
                    weights = model_clone.coef_[0]
                else:
                    # Just take the first class weights for the audit
                    weights = model_clone.coef_[0]
            elif hasattr(model_clone, 'feature_importances_'):
                # For Tree-based models
                weights = model_clone.feature_importances_
            else:
                print("Skipping: Model type does not support feature extraction.")
                continue
            
            # Zip, Sort, and Print
            feats = sorted(zip(weights, feature_names))
            
            print(f"Top 5 Indicative Words:")
            for w, f in feats[-5:]:
                print(f"  {f}: {w:.4f}")

# RUN IT using the new y_encoded
audit_all_models(methods, models_to_test, X_text, y_encoded)
# Out:
# ====================
# AUDIT: Bag of Words
# ====================
#
# --- Model: Logistic Regression ---
# Top 5 Indicative Words:
#   general: 0.9375
#   business: 0.9550
#   new: 1.1531
#   tho: 1.1563
#   says: 1.4345
#
# --- Model: SVM ---
# Top 5 Indicative Words:
#   printing: 0.8577
#   assembly: 0.9170
#   general: 0.9182
#   tho: 1.2513
#   says: 1.5994
#
# --- Model: Random Forest ---
# Top 5 Indicative Words:
#   space: 0.0167
#   said: 0.0178
#   miss: 0.0187
#   ship: 0.0192
#   strong: 0.0255
#
# --- Model: Multinomial Naïve Bayes ---
# Skipping: Model type does not support feature extraction.
#
# --- Model: K-Nearest Neighbors ---
# Skipping: Model type does not support feature extraction.
#
# --- Model: XGBoost ---
# Top 5 Indicative Words:
#   despair: 0.0178
#   strong: 0.0193
#   witch: 0.0229
#   jet: 0.0263
#   governor: 0.0307
#
# ====================
# AUDIT: TF-IDF
# ====================
#
# --- Model: Logistic Regression ---
# Top 5 Indicative Words:
#   general: 1.4162
#   says: 1.6007
#   tho: 1.7179
#   business: 1.7867
#   new: 1.8680
#
# --- Model: SVM ---
# Top 5 Indicative Words:
#   public: 1.3145
#   printing: 1.3738
#   new: 1.7795
#   tho: 1.8917
#   says: 2.0692
#
# --- Model: Random Forest ---
# Top 5 Indicative Words:
#   space: 0.0167
#   said: 0.0177
#   ship: 0.0203
#   miss: 0.0210
#   strong: 0.0264
#
# --- Model: Multinomial Naïve Bayes ---
# Skipping: Model type does not support feature extraction.
#
# --- Model: K-Nearest Neighbors ---
# Skipping: Model type does not support feature extraction.
#
# --- Model: XGBoost ---
# Top 5 Indicative Words:
#   control: 0.0193
#   emerald: 0.0219
#   governor: 0.0220
#   witch: 0.0228
#   jet: 0.0318
#
# ====================
# AUDIT: TF-IDF N-grams
# ====================
#
# --- Model: Logistic Regression ---
# Top 5 Indicative Words:
#   general: 1.4378
#   says: 1.5595
#   new: 1.6500
#   tho: 1.6818
#   business: 1.8361
#
# --- Model: SVM ---
# Top 5 Indicative Words:
#   etc: 1.3427
#   general: 1.3627
#   money: 1.3677
#   tho: 1.6496
#   says: 2.0331
#
# --- Model: Random Forest ---
# Top 5 Indicative Words:
#   ship: 0.0149
#   said: 0.0182
#   space: 0.0188
#   miss: 0.0188
#   strong: 0.0239
#
# --- Model: Multinomial Naïve Bayes ---
# Skipping: Model type does not support feature extraction.
#
# --- Model: K-Nearest Neighbors ---
# Skipping: Model type does not support feature extraction.
#
# --- Model: XGBoost ---
# Top 5 Indicative Words:
#   strong: 0.0193
#   emerald: 0.0208
#   witch: 0.0221
#   jet: 0.0234
#   governor: 0.0382
